# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000,high=90.000, size= 2000)
lngs= np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination. 
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=56704f47c904e41ddefeadd265c03ac2

# %%
#Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sydney mines
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | bucak
# Processing Record 5 of Set 1 | haines junction
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | chuy
# Processing Record 9 of Set 1 | banjar
# Processing Record 10 of Set 1 | grand gaube
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | walvis bay
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | raudeberg
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | batemans bay
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | nhulunbuy
# Processing Record 23 of Set 1 | pacific grove
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | mount isa
# Processing Record 27 of Set 1 | mogadishu
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | harper
# Processing Record 31 of Set 1 | souillac
# Processing Record 32 of Set 1 | varna
# Processing Record 33 of Set 1 | snasa
# Processing Record 34 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | bobo dioulasso
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | lebedinyy
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 46 of Set 1 | tumaco
# Processing Record 47 of Set 1 | constitucion
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | langham
# Processing Record 50 of Set 1 | poum
# Processing Record 1 of Set 2 | leningradskiy
# Processing Record 2 of Set 2 | bodden town
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | nador
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | vao
# Processing Record 7 of Set 2 | slobodskoy
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | hailar
# Processing Record 11 of Set 2 | lakota
# Processing Record 12 of Set 2 | gaoual
# Processing Record 13 of Set 2 | freeport
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | usinsk
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | nicoya
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | menongue
# Processing Record 23 of Set 2 | torbay
# Processing Record 24 of Set 2 | olafsvik
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | sabalgarh
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | tessalit
# Processing Record 29 of Set 2 | sao joao da barra
# Processing Record 30 of Set 2 | moranbah
# Processing Record 31 of Set 2 | chimoio
# Processing Record 32 of Set 2 | rocha
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | jacareacanga
# Processing Record 36 of Set 2 | marzuq
# Processing Record 37 of Set 2 | asfi
# Processing Record 38 of Set 2 | chanika
# Processing Record 39 of Set 2 | nome
# Processing Record 40 of Set 2 | san quintin
# Processing Record 41 of Set 2 | belaya gora
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | bumba
# Processing Record 44 of Set 2 | nago
# Processing Record 45 of Set 2 | hachinohe
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 2 | mazyr
# Processing Record 49 of Set 2 | nanga eboko
# Processing Record 50 of Set 2 | north bend
# Processing Record 1 of Set 3 | beringovskiy
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | la romana
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | pevek
# Processing Record 7 of Set 3 | pueblo
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | fuerte olimpo
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | jumla
# Processing Record 13 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | sorland
# Processing Record 16 of Set 3 | kavaratti
# Processing Record 17 of Set 3 | pisco
# Processing Record 18 of Set 3 | helena
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | bilibino
# Processing Record 22 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 3 | rypefjord
# Processing Record 24 of Set 3 | tucurui
# Processing Record 25 of Set 3 | kodar
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | koundara
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | porto velho
# Processing Record 33 of Set 3 | saint anthony
# Processing Record 34 of Set 3 | rincon
# Processing Record 35 of Set 3 | batagay-alyta
# Processing Record 36 of Set 3 | pangnirtung
# Processing Record 37 of Set 3 | nuuk
# Processing Record 38 of Set 3 | whitefish
# Processing Record 39 of Set 3 | corvallis
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | methoni
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | ayan
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | seoul
# Processing Record 46 of Set 3 | jobat
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | la crosse
# Processing Record 50 of Set 3 | truckee
# Processing Record 1 of Set 4 | verkhoyansk
# Processing Record 2 of Set 4 | laguna
# Processing Record 3 of Set 4 | sorong
# Processing Record 4 of Set 4 | los llanos de aridane
# Processing Record 5 of Set 4 | padang
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | semey
# Processing Record 8 of Set 4 | mehtar lam
# Processing Record 9 of Set 4 | sechelt
# Processing Record 10 of Set 4 | pilar
# Processing Record 11 of Set 4 | sault sainte marie
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | singaparna
# Processing Record 14 of Set 4 | taoudenni
# Processing Record 15 of Set 4 | cabedelo
# Processing Record 16 of Set 4 | hay river
# Processing Record 17 of Set 4 | sao miguel do araguaia
# Processing Record 18 of Set 4 | kachiry
# Processing Record 19 of Set 4 | namibe
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | te anau
# Processing Record 22 of Set 4 | gat
# Processing Record 23 of Set 4 | tigil
# Processing Record 24 of Set 4 | sola
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | fomboni
# Processing Record 27 of Set 4 | yelizovo
# Processing Record 28 of Set 4 | bac lieu
# Processing Record 29 of Set 4 | newala
# Processing Record 30 of Set 4 | marquette
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | siderno
# Processing Record 34 of Set 4 | tual
# Processing Record 35 of Set 4 | vidim
# Processing Record 36 of Set 4 | vanimo
# Processing Record 37 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 4 | saumur
# Processing Record 39 of Set 4 | santiago de cao
# Processing Record 40 of Set 4 | takoradi
# Processing Record 41 of Set 4 | newport
# Processing Record 42 of Set 4 | manacapuru
# Processing Record 43 of Set 4 | szubin
# Processing Record 44 of Set 4 | fayetteville
# Processing Record 45 of Set 4 | zlitan
# Processing Record 46 of Set 4 | muros
# Processing Record 47 of Set 4 | barrow
# Processing Record 48 of Set 4 | glencoe
# Processing Record 49 of Set 4 | whitehorse
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | roald
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | pychas
# Processing Record 4 of Set 5 | santa fe
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | strathpeffer
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | georgetown
# Processing Record 9 of Set 5 | sao jose da coroa grande
# Processing Record 10 of Set 5 | upernavik
# Processing Record 11 of Set 5 | qaanaaq
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | mana
# Processing Record 14 of Set 5 | buala
# Processing Record 15 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 16 of Set 5 | santa rosa
# Processing Record 17 of Set 5 | lawrenceburg
# Processing Record 18 of Set 5 | solnechnyy
# Processing Record 19 of Set 5 | sisophon
# Processing Record 20 of Set 5 | sardulgarh
# Processing Record 21 of Set 5 | port-cartier
# Processing Record 22 of Set 5 | saint-joseph
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | camopi
# Processing Record 25 of Set 5 | jambi
# Processing Record 26 of Set 5 | caucaia
# Processing Record 27 of Set 5 | novi iskar
# Processing Record 28 of Set 5 | mount gambier
# Processing Record 29 of Set 5 | marienburg
# Processing Record 30 of Set 5 | linxia
# Processing Record 31 of Set 5 | kununurra
# Processing Record 32 of Set 5 | veraval
# Processing Record 33 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | ulaanbaatar
# Processing Record 36 of Set 5 | hanzhong
# Processing Record 37 of Set 5 | korla
# Processing Record 38 of Set 5 | vestmannaeyjar
# Processing Record 39 of Set 5 | casma
# Processing Record 40 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 41 of Set 5 | chickasha
# Processing Record 42 of Set 5 | sanchor
# Processing Record 43 of Set 5 | chokurdakh
# Processing Record 44 of Set 5 | buraydah
# Processing Record 45 of Set 5 | orje
# Processing Record 46 of Set 5 | matara
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | yabelo
# Processing Record 49 of Set 5 | shelburne
# Processing Record 50 of Set 5 | yar-sale
# Processing Record 1 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 6 | sao filipe
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | waddan
# Processing Record 5 of Set 6 | taguatinga
# Processing Record 6 of Set 6 | calvia
# Processing Record 7 of Set 6 | acapulco
# Processing Record 8 of Set 6 | halifax
# Processing Record 9 of Set 6 | east london
# Processing Record 10 of Set 6 | severo-kurilsk
# Processing Record 11 of Set 6 | karakol
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | alice springs
# Processing Record 14 of Set 6 | ningyang
# Processing Record 15 of Set 6 | brigantine
# Processing Record 16 of Set 6 | dwarka
# Processing Record 17 of Set 6 | abu dhabi
# Processing Record 18 of Set 6 | aykino
# Processing Record 19 of Set 6 | dakar
# Processing Record 20 of Set 6 | fortuna
# Processing Record 21 of Set 6 | ohara
# Processing Record 22 of Set 6 | khor
# Processing Record 23 of Set 6 | guarapari
# Processing Record 24 of Set 6 | mitsamiouli
# Processing Record 25 of Set 6 | itarema
# Processing Record 26 of Set 6 | surt
# Processing Record 27 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 6 | hasaki
# Processing Record 29 of Set 6 | vitim
# Processing Record 30 of Set 6 | tahe
# Processing Record 31 of Set 6 | middletown
# Processing Record 32 of Set 6 | oksfjord
# Processing Record 33 of Set 6 | aketi
# Processing Record 34 of Set 6 | burnie
# Processing Record 35 of Set 6 | warkworth
# Processing Record 36 of Set 6 | ahipara
# Processing Record 37 of Set 6 | eyl
# Processing Record 38 of Set 6 | kassala
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | san clemente
# Processing Record 41 of Set 6 | culipapa
# City not found. Skipping...
# Processing Record 42 of Set 6 | bograd
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | smithers
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 6 | diffa
# Processing Record 49 of Set 6 | mocuba
# Processing Record 50 of Set 6 | komatipoort
# Processing Record 1 of Set 7 | manhattan
# Processing Record 2 of Set 7 | safford
# Processing Record 3 of Set 7 | kudahuvadhoo
# Processing Record 4 of Set 7 | tabou
# Processing Record 5 of Set 7 | longhua
# Processing Record 6 of Set 7 | barrhead
# Processing Record 7 of Set 7 | sao felix do xingu
# Processing Record 8 of Set 7 | luderitz
# Processing Record 9 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 7 | robe
# Processing Record 11 of Set 7 | mumford
# Processing Record 12 of Set 7 | balykshi
# Processing Record 13 of Set 7 | salinas
# Processing Record 14 of Set 7 | olinda
# Processing Record 15 of Set 7 | rawson
# Processing Record 16 of Set 7 | bathsheba
# Processing Record 17 of Set 7 | vila velha
# Processing Record 18 of Set 7 | rock springs
# Processing Record 19 of Set 7 | soyo
# Processing Record 20 of Set 7 | ixtapa
# Processing Record 21 of Set 7 | longyearbyen
# Processing Record 22 of Set 7 | sterling
# Processing Record 23 of Set 7 | shizunai
# Processing Record 24 of Set 7 | mayo
# Processing Record 25 of Set 7 | venado tuerto
# Processing Record 26 of Set 7 | jalu
# Processing Record 27 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | faanui
# Processing Record 30 of Set 7 | esperance
# Processing Record 31 of Set 7 | nishihara
# Processing Record 32 of Set 7 | vangaindrano
# Processing Record 33 of Set 7 | labuhan
# Processing Record 34 of Set 7 | san patricio
# Processing Record 35 of Set 7 | lata
# Processing Record 36 of Set 7 | ouesso
# Processing Record 37 of Set 7 | burgeo
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | malatya
# Processing Record 40 of Set 7 | pampa
# Processing Record 41 of Set 7 | hami
# Processing Record 42 of Set 7 | puerto maldonado
# Processing Record 43 of Set 7 | carroll
# Processing Record 44 of Set 7 | nantucket
# Processing Record 45 of Set 7 | nueva loja
# Processing Record 46 of Set 7 | labytnangi
# Processing Record 47 of Set 7 | adelaide
# Processing Record 48 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 7 | picayune
# Processing Record 50 of Set 7 | arman
# Processing Record 1 of Set 8 | olga
# Processing Record 2 of Set 8 | vossevangen
# Processing Record 3 of Set 8 | san jose de rio tinto
# Processing Record 4 of Set 8 | brae
# Processing Record 5 of Set 8 | bandarbeyla
# Processing Record 6 of Set 8 | trairi
# Processing Record 7 of Set 8 | nidzica
# Processing Record 8 of Set 8 | miraflores
# Processing Record 9 of Set 8 | makakilo city
# Processing Record 10 of Set 8 | baykit
# Processing Record 11 of Set 8 | luganville
# Processing Record 12 of Set 8 | vardo
# Processing Record 13 of Set 8 | bensonville
# Processing Record 14 of Set 8 | voznesenye
# Processing Record 15 of Set 8 | venezuela
# Processing Record 16 of Set 8 | horodnytsya
# Processing Record 17 of Set 8 | agadez
# Processing Record 18 of Set 8 | sibolga
# Processing Record 19 of Set 8 | chernyshevskiy
# Processing Record 20 of Set 8 | hirara
# Processing Record 21 of Set 8 | marystown
# Processing Record 22 of Set 8 | luanda
# Processing Record 23 of Set 8 | adrar
# Processing Record 24 of Set 8 | richards bay
# Processing Record 25 of Set 8 | aklavik
# Processing Record 26 of Set 8 | san jorge
# Processing Record 27 of Set 8 | koumac
# Processing Record 28 of Set 8 | menomonie
# Processing Record 29 of Set 8 | ouallam
# Processing Record 30 of Set 8 | teguise
# Processing Record 31 of Set 8 | kautokeino
# Processing Record 32 of Set 8 | along
# Processing Record 33 of Set 8 | vung tau
# Processing Record 34 of Set 8 | tura
# Processing Record 35 of Set 8 | zhigansk
# Processing Record 36 of Set 8 | kaduqli
# Processing Record 37 of Set 8 | ravar
# Processing Record 38 of Set 8 | great falls
# Processing Record 39 of Set 8 | akyab
# Processing Record 40 of Set 8 | wuning
# Processing Record 41 of Set 8 | correntina
# Processing Record 42 of Set 8 | waipawa
# Processing Record 43 of Set 8 | norman wells
# Processing Record 44 of Set 8 | najran
# Processing Record 45 of Set 8 | gorontalo
# Processing Record 46 of Set 8 | rio grande
# Processing Record 47 of Set 8 | kruisfontein
# Processing Record 48 of Set 8 | igrim
# Processing Record 49 of Set 8 | sao marcos
# Processing Record 50 of Set 8 | arraial do cabo
# Processing Record 1 of Set 9 | aksarka
# Processing Record 2 of Set 9 | rafraf
# Processing Record 3 of Set 9 | hamilton
# Processing Record 4 of Set 9 | marawi
# Processing Record 5 of Set 9 | lagos
# Processing Record 6 of Set 9 | dingle
# Processing Record 7 of Set 9 | san giovanni valdarno
# Processing Record 8 of Set 9 | gamba
# Processing Record 9 of Set 9 | pangkalanbuun
# Processing Record 10 of Set 9 | asau
# Processing Record 11 of Set 9 | cherskiy
# Processing Record 12 of Set 9 | hobyo
# Processing Record 13 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 14 of Set 9 | bayan
# Processing Record 15 of Set 9 | batticaloa
# Processing Record 16 of Set 9 | kunya
# Processing Record 17 of Set 9 | bhanjanagar
# Processing Record 18 of Set 9 | bossier city
# Processing Record 19 of Set 9 | lichinga
# Processing Record 20 of Set 9 | berbera
# Processing Record 21 of Set 9 | port hedland
# Processing Record 22 of Set 9 | tommot
# Processing Record 23 of Set 9 | lima
# Processing Record 24 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 9 | faya
# Processing Record 26 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 9 | tarakan
# Processing Record 28 of Set 9 | emmett
# Processing Record 29 of Set 9 | maniitsoq
# Processing Record 30 of Set 9 | port macquarie
# Processing Record 31 of Set 9 | ust-barguzin
# Processing Record 32 of Set 9 | tokmak
# Processing Record 33 of Set 9 | green river
# Processing Record 34 of Set 9 | shingu
# Processing Record 35 of Set 9 | broome
# Processing Record 36 of Set 9 | kita
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | nouadhibou
# Processing Record 39 of Set 9 | carballo
# Processing Record 40 of Set 9 | touho
# Processing Record 41 of Set 9 | mao
# Processing Record 42 of Set 9 | huilong
# Processing Record 43 of Set 9 | puerto baquerizo moreno
# Processing Record 44 of Set 9 | ilulissat
# Processing Record 45 of Set 9 | qingdao
# Processing Record 46 of Set 9 | nuevo laredo
# Processing Record 47 of Set 9 | ruteng
# Processing Record 48 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 9 | abonnema
# Processing Record 50 of Set 9 | itaituba
# Processing Record 1 of Set 10 | dehui
# Processing Record 2 of Set 10 | kaeo
# Processing Record 3 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 10 | road town
# Processing Record 5 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 6 of Set 10 | avera
# Processing Record 7 of Set 10 | saldanha
# Processing Record 8 of Set 10 | aswan
# Processing Record 9 of Set 10 | ampanihy
# Processing Record 10 of Set 10 | saint-augustin
# Processing Record 11 of Set 10 | pogranichnyy
# Processing Record 12 of Set 10 | samaipata
# Processing Record 13 of Set 10 | krasnoborsk
# Processing Record 14 of Set 10 | carman
# Processing Record 15 of Set 10 | lorengau
# Processing Record 16 of Set 10 | vallecillo
# Processing Record 17 of Set 10 | sambava
# Processing Record 18 of Set 10 | znamenskoye
# Processing Record 19 of Set 10 | looc
# Processing Record 20 of Set 10 | luangwa
# Processing Record 21 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 10 | mandurah
# Processing Record 23 of Set 10 | xuddur
# Processing Record 24 of Set 10 | narasannapeta
# Processing Record 25 of Set 10 | bam
# Processing Record 26 of Set 10 | okhtyrka
# Processing Record 27 of Set 10 | fukue
# Processing Record 28 of Set 10 | george town
# Processing Record 29 of Set 10 | astara
# Processing Record 30 of Set 10 | lagoa
# Processing Record 31 of Set 10 | ust-ilimsk
# Processing Record 32 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 10 | clyde river
# Processing Record 34 of Set 10 | sabha
# Processing Record 35 of Set 10 | martapura
# Processing Record 36 of Set 10 | cayenne
# Processing Record 37 of Set 10 | qinhuangdao
# Processing Record 38 of Set 10 | melilla
# Processing Record 39 of Set 10 | vostok
# Processing Record 40 of Set 10 | lasa
# Processing Record 41 of Set 10 | benguela
# Processing Record 42 of Set 10 | tateyama
# Processing Record 43 of Set 10 | port lincoln
# Processing Record 44 of Set 10 | mecca
# Processing Record 45 of Set 10 | taldan
# Processing Record 46 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 10 | normandin
# Processing Record 48 of Set 10 | zaporizhzhya
# Processing Record 49 of Set 10 | konakovo
# Processing Record 50 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 11 | altagracia de orituco
# Processing Record 2 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 11 | yulara
# Processing Record 4 of Set 11 | cruzeiro do sul
# Processing Record 5 of Set 11 | nelson bay
# Processing Record 6 of Set 11 | san francisco
# Processing Record 7 of Set 11 | villamontes
# Processing Record 8 of Set 11 | bilma
# Processing Record 9 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 11 | zhangjiakou
# Processing Record 12 of Set 11 | santiago
# Processing Record 13 of Set 11 | luang prabang
# Processing Record 14 of Set 11 | loikaw
# Processing Record 15 of Set 11 | srednekolymsk
# Processing Record 16 of Set 11 | doha
# Processing Record 17 of Set 11 | dawlatabad
# Processing Record 18 of Set 11 | kargasok
# Processing Record 19 of Set 11 | wenling
# Processing Record 20 of Set 11 | deloraine
# Processing Record 21 of Set 11 | big spring
# Processing Record 22 of Set 11 | fujin
# Processing Record 23 of Set 11 | ostrovnoy
# Processing Record 24 of Set 11 | saint-francois
# Processing Record 25 of Set 11 | kathu
# Processing Record 26 of Set 11 | mutis
# Processing Record 27 of Set 11 | torres
# Processing Record 28 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 11 | zimovniki
# Processing Record 30 of Set 11 | bugene
# Processing Record 31 of Set 11 | talalayivka
# Processing Record 32 of Set 11 | pahrump
# Processing Record 33 of Set 11 | horsham
# Processing Record 34 of Set 11 | loreto
# Processing Record 35 of Set 11 | dolgoderevenskoye
# Processing Record 36 of Set 11 | levelland
# Processing Record 37 of Set 11 | novopokrovka
# Processing Record 38 of Set 11 | plettenberg bay
# Processing Record 39 of Set 11 | huntsville
# Processing Record 40 of Set 11 | mungwi
# Processing Record 41 of Set 11 | isilkul
# Processing Record 42 of Set 11 | bontang
# Processing Record 43 of Set 11 | morwell
# Processing Record 44 of Set 11 | balagansk
# Processing Record 45 of Set 11 | langsa
# Processing Record 46 of Set 11 | mbuji-mayi
# Processing Record 47 of Set 11 | mizan teferi
# Processing Record 48 of Set 11 | pingliang
# Processing Record 49 of Set 11 | bezhta
# Processing Record 50 of Set 11 | mapiripan
# Processing Record 1 of Set 12 | mendi
# Processing Record 2 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 12 | vysokogornyy
# Processing Record 4 of Set 12 | carson city
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | zatoka
# Processing Record 7 of Set 12 | flin flon
# Processing Record 8 of Set 12 | longonjo
# Processing Record 9 of Set 12 | blankenberge
# Processing Record 10 of Set 12 | pio ix
# Processing Record 11 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 12 | gogrial
# Processing Record 13 of Set 12 | caruray
# Processing Record 14 of Set 12 | mason city
# Processing Record 15 of Set 12 | klyuchi
# Processing Record 16 of Set 12 | entre rios
# Processing Record 17 of Set 12 | anchorage
# Processing Record 18 of Set 12 | fort nelson
# Processing Record 19 of Set 12 | camacha
# Processing Record 20 of Set 12 | grootfontein
# Processing Record 21 of Set 12 | ulkan
# Processing Record 22 of Set 12 | salalah
# Processing Record 23 of Set 12 | okhotsk
# Processing Record 24 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 12 | grindavik
# Processing Record 26 of Set 12 | veshkayma
# Processing Record 27 of Set 12 | kashi
# Processing Record 28 of Set 12 | dickinson
# Processing Record 29 of Set 12 | margate
# Processing Record 30 of Set 12 | portland
# Processing Record 31 of Set 12 | acajutla
# Processing Record 32 of Set 12 | salym
# Processing Record 33 of Set 12 | pochutla
# Processing Record 34 of Set 12 | porto belo
# Processing Record 35 of Set 12 | kihei
# Processing Record 36 of Set 12 | san ignacio
# Processing Record 37 of Set 12 | la ronge
# Processing Record 38 of Set 12 | atar
# Processing Record 39 of Set 12 | kamenka
# Processing Record 40 of Set 12 | svetlyy
# Processing Record 41 of Set 12 | puerto palomas
# Processing Record 42 of Set 12 | meulaboh
# Processing Record 43 of Set 12 | asyut
# Processing Record 44 of Set 12 | centralia
# Processing Record 45 of Set 12 | yongan
# Processing Record 46 of Set 12 | peniche
# Processing Record 47 of Set 12 | vadso
# Processing Record 48 of Set 12 | mukhanovo
# City not found. Skipping...
# Processing Record 49 of Set 12 | viedma
# Processing Record 50 of Set 12 | nelson
# Processing Record 1 of Set 13 | sabang
# Processing Record 2 of Set 13 | tiznit
# Processing Record 3 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 13 | porto novo
# Processing Record 5 of Set 13 | kenai
# Processing Record 6 of Set 13 | passo fundo
# Processing Record 7 of Set 13 | jurado
# Processing Record 8 of Set 13 | chilca
# Processing Record 9 of Set 13 | gizo
# Processing Record 10 of Set 13 | breukelen
# Processing Record 11 of Set 13 | luancheng
# Processing Record 12 of Set 13 | juneau
# Processing Record 13 of Set 13 | isangel
# Processing Record 14 of Set 13 | samarai
# Processing Record 15 of Set 13 | krasnoselkup
# Processing Record 16 of Set 13 | moralillo
# Processing Record 17 of Set 13 | liaocheng
# Processing Record 18 of Set 13 | taree
# Processing Record 19 of Set 13 | hualmay
# Processing Record 20 of Set 13 | kysyl-syr
# Processing Record 21 of Set 13 | eureka
# Processing Record 22 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 13 | antunez
# Processing Record 25 of Set 13 | fairbanks
# Processing Record 26 of Set 13 | chimbote
# Processing Record 27 of Set 13 | novooleksiyivka
# Processing Record 28 of Set 13 | hokitika
# Processing Record 29 of Set 13 | guerrero negro
# Processing Record 30 of Set 13 | aleksandrov gay
# Processing Record 31 of Set 13 | chiredzi
# Processing Record 32 of Set 13 | biloela
# Processing Record 33 of Set 13 | alta floresta
# Processing Record 34 of Set 13 | westport
# Processing Record 35 of Set 13 | necochea
# Processing Record 36 of Set 13 | cairns
# Processing Record 37 of Set 13 | perpignan
# Processing Record 38 of Set 13 | dores do indaia
# Processing Record 39 of Set 13 | jiaohe
# Processing Record 40 of Set 13 | amazar
# Processing Record 41 of Set 13 | iquique
# Processing Record 42 of Set 13 | pozhva
# Processing Record 43 of Set 13 | castlecomer
# Processing Record 44 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 13 | joinville
# Processing Record 46 of Set 13 | logrono
# Processing Record 47 of Set 13 | miramar
# Processing Record 48 of Set 13 | santa quiteria do maranhao
# Processing Record 49 of Set 13 | hambantota
# Processing Record 50 of Set 13 | svetlogorsk
# Processing Record 1 of Set 14 | apeldoorn
# Processing Record 2 of Set 14 | san joaquin
# Processing Record 3 of Set 14 | coahuayana
# Processing Record 4 of Set 14 | riyadh
# Processing Record 5 of Set 14 | kombissiri
# Processing Record 6 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 14 | naze
# Processing Record 8 of Set 14 | guhagar
# Processing Record 9 of Set 14 | pavlovka
# Processing Record 10 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 14 | horta
# Processing Record 12 of Set 14 | miram shah
# Processing Record 13 of Set 14 | statesville
# Processing Record 14 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 15 of Set 14 | ishigaki
# Processing Record 16 of Set 14 | riberalta
# Processing Record 17 of Set 14 | kirkenaer
# Processing Record 18 of Set 14 | abu samrah
# Processing Record 19 of Set 14 | ahvaz
# Processing Record 20 of Set 14 | beian
# Processing Record 21 of Set 14 | waitati
# Processing Record 22 of Set 14 | aykhal
# Processing Record 23 of Set 14 | shakhty
# Processing Record 24 of Set 14 | joao pinheiro
# Processing Record 25 of Set 14 | shahreza
# Processing Record 26 of Set 14 | camapua
# Processing Record 27 of Set 14 | cap malheureux
# Processing Record 28 of Set 14 | bereda
# Processing Record 29 of Set 14 | ban phai
# Processing Record 30 of Set 14 | caibarien
# Processing Record 31 of Set 14 | kieta
# Processing Record 32 of Set 14 | champerico
# Processing Record 33 of Set 14 | tamandare
# Processing Record 34 of Set 14 | ouadda
# Processing Record 35 of Set 14 | itoman
# Processing Record 36 of Set 14 | sept-iles
# Processing Record 37 of Set 14 | streator
# Processing Record 38 of Set 14 | dhidhdhoo
# Processing Record 39 of Set 14 | alekseyevsk
# Processing Record 40 of Set 14 | labuan
# Processing Record 41 of Set 14 | mahibadhoo
# Processing Record 42 of Set 14 | belaya
# Processing Record 43 of Set 14 | biltine
# Processing Record 44 of Set 14 | taksimo
# Processing Record 45 of Set 14 | kungurtug
# Processing Record 46 of Set 14 | mae hong son
# Processing Record 47 of Set 14 | monrovia
# Processing Record 48 of Set 14 | altay
# Processing Record 49 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 50 of Set 14 | aitape
# Processing Record 1 of Set 15 | koindu
# Processing Record 2 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 3 of Set 15 | polewali
# Processing Record 4 of Set 15 | severomuysk
# Processing Record 5 of Set 15 | pingxiang
# Processing Record 6 of Set 15 | mackenzie
# Processing Record 7 of Set 15 | aubenas
# Processing Record 8 of Set 15 | black river
# Processing Record 9 of Set 15 | lhokseumawe
# Processing Record 10 of Set 15 | san cristobal
# Processing Record 11 of Set 15 | mamontovo
# Processing Record 12 of Set 15 | mezen
# Processing Record 13 of Set 15 | kananga
# Processing Record 14 of Set 15 | san rafael del sur
# Processing Record 15 of Set 15 | ballina
# Processing Record 16 of Set 15 | santarem
# Processing Record 17 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 18 of Set 15 | aktau
# Processing Record 19 of Set 15 | soria
# Processing Record 20 of Set 15 | xichang
# Processing Record 21 of Set 15 | danville
# Processing Record 22 of Set 15 | anadyr
# Processing Record 23 of Set 15 | rize
# Processing Record 24 of Set 15 | jiuquan
# Processing Record 25 of Set 15 | kilindoni
# Processing Record 26 of Set 15 | arlit
# Processing Record 27 of Set 15 | ulaangom
# Processing Record 28 of Set 15 | sakakah
# Processing Record 29 of Set 15 | carberry
# Processing Record 30 of Set 15 | mushie
# Processing Record 31 of Set 15 | concepcion del oro
# Processing Record 32 of Set 15 | glendive
# Processing Record 33 of Set 15 | balkanabat
# Processing Record 34 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 15 | ueckermunde
# Processing Record 36 of Set 15 | awbari
# Processing Record 37 of Set 15 | crotone
# Processing Record 38 of Set 15 | tabas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#               City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Sydney Mines      CA   46.24   -60.22     70.25        87          75
# 1           Kodiak      US   57.79  -152.41     49.51        82           7
# 2     Puerto Ayora      EC   -0.74   -90.35     67.55       100         100
# 3            Bucak      TR   37.46    30.59     88.32        36          62
# 4  Haines Junction      CA   60.75  -137.51     37.35        87          92
# 5            Bluff      NZ  -46.60   168.33     39.79        62          69
# 6           Albany      US   42.60   -73.97     62.64        92         100
# 7             Chuy      UY  -33.70   -53.46     59.94        53           0
# 8           Banjar      ID   -8.19   114.97     78.44        87         100
# 9      Grand Gaube      MU  -20.01    57.66     73.80        71           3
#
#    Wind Speed Current Description
# 0       12.66       broken clouds
# 1        3.33           clear sky
# 2        7.00     overcast clouds
# 3        6.87       broken clouds
# 4        3.44     overcast clouds
# 5       10.85       broken clouds
# 6        2.13          light rain
# 7        2.66           clear sky
# 8        2.57     overcast clouds
# 9        8.99           clear sky

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
